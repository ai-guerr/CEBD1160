# %%
def printHeader(x):
    print("**************************************************************************************************************")
    print(x)
    print("**************************************************************************************************************")
    print('\n')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %%
import os
os.getcwd()
#os.chdir('/Users/....')
# Out:
# 'C:\\Users\\anthea.guerra\\OneDrive - Accenture\\Desktop\\2019\\Big Data Studies\\CEBD1160\\A5'

# %%
printHeader("Boxplot Graph:")
plt.figure(figsize=(9, 8))
plt.figure(figsize=(25, 15))
sns.boxplot(x="Fare", y="Sex", data=df, palette="Set2");

print("Key observations:")
print("1. Overall, the range of women's ticket fares is wider than that of men's ticket fares.")
print("2. Nearly half of the women's ticket fares exceed three quarters of the men's ticket fares.")
print("3. The number of outlier fares for men is higher than the number of outlier fares for women.")
print("4. For the outliers representing the highest fares, the women's and men's fares are aligned. This suggests they could have been sold in pairs.")
# Out:
# **************************************************************************************************************
# Boxplot Graph:
# **************************************************************************************************************
#
#
# Key observations:
# 1. Overall, the range of women's ticket fares is wider than that of men's ticket fares.
# 2. Nearly half of the women's ticket fares exceed three quarters of the men's ticket fares.
# 3. The number of outlier fares for men is higher than the number of outlier fares for women.
# 4. For the outliers representing the highest fares, the women's and men's fares are aligned. This suggests they could have been sold in pairs.
